# %%
# Import Dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import requests
import time

# %%
# Generate 2,000 Random numbers for latitude and longitude
lats = np.random.uniform(-90, 90, 2000)
lngs = np.random.uniform(-180, 180, 2000)
lats_lngs = zip(lats, lngs)
coordinates = list(lats_lngs)

# %%
# Get the nearest cities using the citipy module
cities = []

# Loop through coordinates
for coord in coordinates:
    # use coordinate indexes and .city_name
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    # append cities list
    if city not in cities:
        cities.append(city)
cities[:10], len(cities)
# Out:
# ['kavieng',
#  'east london',
#  'geraldton',
#  'rikitea',
#  'nikolskoye',
#  'hobart',
#  'hermanus',
#  'busselton',
#  'arraial do cabo',
#  'rafsanjan']

# %%
# import api key
from config import weather_api_key

# %%
# Perform an API call with the OpenWeatherMap

# Create base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

cities_data = []
record_counter = 1
set_counter = 1
print("Beginning City Data Retrieval Process")
print("---------------------------")
# Iterate cities list to pull data for each city
for index, city in enumerate(cities):
       
    # Adjust set and record counters
    if (index % 50 == 0 and index >= 50):
        set_counter += 1
        record_counter = 1
        print("Waiting 1 minute to start new set")
        time.sleep(60)
        
    # Build query URL
    query_url = f"{url}q={city.replace(' ', '+')}&units=imperial&appid={weather_api_key}"
    
    print(f"Retrieving data Record {record_counter} of Set {set_counter} | {city.title()}")    
    
    # +1 to record counter
    record_counter += 1
    try:       
        # API get request, response call to retrieve city data
        response = requests.get(query_url).json()
        # Lat/Lng
        lat = response['coord']['lat']
        lng = response['coord']['lon']
        # Max Temp
        max_temp = response['main']['temp_max']
        # Humidity
        humidity = response['main']['humidity']
        # Cloudiness
        cloudiness = response['clouds']['all']
        # Wind Speed
        wind_speed = response['wind']['speed']
        # Weather description
        weather = response['weather'][0]['description']
        # Country
        country = response['sys']['country']
        cities_data.append({
            "City": city.title(),
            "Country": country,
            "Latitude": lat,
            "Longitude": lng,
            "Max Temperature": max_temp,
            "Percent Humidity": humidity,
            "Percent Cloudiness": cloudiness,
            "Wind Speed": wind_speed,
            "Weather Description": weather
        })
        
    except: # when error in retrieving
        print("City data not found, skipping... ")
        pass 
    
print("-----------------------------")
print("Finished City Data Detrieval Process")
print("-----------------------------")
# Out:
# Beginning City Data Retrieval Process
# ---------------------------
# Retrieving data Record 1 of Set 1 | Kavieng
# Retrieving data Record 2 of Set 1 | East London
# Retrieving data Record 3 of Set 1 | Geraldton
# Retrieving data Record 4 of Set 1 | Rikitea
# Retrieving data Record 5 of Set 1 | Nikolskoye
# Retrieving data Record 6 of Set 1 | Hobart
# Retrieving data Record 7 of Set 1 | Hermanus
# Retrieving data Record 8 of Set 1 | Busselton
# Retrieving data Record 9 of Set 1 | Arraial Do Cabo
# Retrieving data Record 10 of Set 1 | Rafsanjan
# Retrieving data Record 11 of Set 1 | Tuktoyaktuk
# Retrieving data Record 12 of Set 1 | Parabel
# Retrieving data Record 13 of Set 1 | Punta Arenas
# Retrieving data Record 14 of Set 1 | Bronnoysund
# Retrieving data Record 15 of Set 1 | Yellowknife
# Retrieving data Record 16 of Set 1 | Srednekolymsk
# Retrieving data Record 17 of Set 1 | Nizhneyansk
# City data not found, skipping...
# Retrieving data Record 18 of Set 1 | Kochevo
# Retrieving data Record 19 of Set 1 | Kurumkan
# Retrieving data Record 20 of Set 1 | Lebu
# Retrieving data Record 21 of Set 1 | Champerico
# Retrieving data Record 22 of Set 1 | Fortuna
# Retrieving data Record 23 of Set 1 | Mataura
# Retrieving data Record 24 of Set 1 | New Norfolk
# Retrieving data Record 25 of Set 1 | Magistralnyy
# Retrieving data Record 26 of Set 1 | Butaritari
# Retrieving data Record 27 of Set 1 | Kaitangata
# Retrieving data Record 28 of Set 1 | Ucluelet
# Retrieving data Record 29 of Set 1 | Chokurdakh
# Retrieving data Record 30 of Set 1 | Kapaa
# Retrieving data Record 31 of Set 1 | Osa
# Retrieving data Record 32 of Set 1 | Balikpapan
# Retrieving data Record 33 of Set 1 | Hofn
# Retrieving data Record 34 of Set 1 | Constitucion
# Retrieving data Record 35 of Set 1 | Ancud
# Retrieving data Record 36 of Set 1 | Saint-Pierre
# Retrieving data Record 37 of Set 1 | Huilong
# Retrieving data Record 38 of Set 1 | Villa Bruzual
# Retrieving data Record 39 of Set 1 | Beneditinos
# Retrieving data Record 40 of Set 1 | Dingle
# Retrieving data Record 41 of Set 1 | Yinchuan
# Retrieving data Record 42 of Set 1 | Itoman
# Retrieving data Record 43 of Set 1 | Gezing
# Retrieving data Record 44 of Set 1 | Mikhaylovka
# Retrieving data Record 45 of Set 1 | Partizanskoye
# Retrieving data Record 46 of Set 1 | Mozarlandia
# Retrieving data Record 47 of Set 1 | Husavik
# Retrieving data Record 48 of Set 1 | Vostok
# Retrieving data Record 49 of Set 1 | Ushuaia
# Retrieving data Record 50 of Set 1 | Sabratah
# Waiting 1 minute to start new set
# Retrieving data Record 1 of Set 2 | Cravo Norte
# Retrieving data Record 2 of Set 2 | Ranau
# Retrieving data Record 3 of Set 2 | Port Elizabeth
# Retrieving data Record 4 of Set 2 | Binika
# Retrieving data Record 5 of Set 2 | Samarai
# Retrieving data Record 6 of Set 2 | Barrow
# Retrieving data Record 7 of Set 2 | Cherskiy
# Retrieving data Record 8 of Set 2 | Amderma
# City data not found, skipping...
# Retrieving data Record 9 of Set 2 | Rangpur
# Retrieving data Record 10 of Set 2 | Chake Chake
# Retrieving data Record 11 of Set 2 | Chiang Mai
# Retrieving data Record 12 of Set 2 | Rio Grande
# Retrieving data Record 13 of Set 2 | Tuzha
# Retrieving data Record 14 of Set 2 | Luang Prabang
# Retrieving data Record 15 of Set 2 | Vila Velha
# Retrieving data Record 16 of Set 2 | Bluff
# Retrieving data Record 17 of Set 2 | Bundaberg
# Retrieving data Record 18 of Set 2 | Mahebourg
# Retrieving data Record 19 of Set 2 | Dikson
# Retrieving data Record 20 of Set 2 | Kruisfontein
# Retrieving data Record 21 of Set 2 | Codrington
# Retrieving data Record 22 of Set 2 | Nanortalik
# Retrieving data Record 23 of Set 2 | Leningradskiy
# Retrieving data Record 24 of Set 2 | Albany
# Retrieving data Record 25 of Set 2 | Hami
# Retrieving data Record 26 of Set 2 | Mar Del Plata
# Retrieving data Record 27 of Set 2 | Waipawa
# Retrieving data Record 28 of Set 2 | Puerto Ayacucho
# Retrieving data Record 29 of Set 2 | Mount Gambier
# Retrieving data Record 30 of Set 2 | Chabahar
# Retrieving data Record 31 of Set 2 | Katsuura
# Retrieving data Record 32 of Set 2 | Avarua
# Retrieving data Record 33 of Set 2 | Faanui
# Retrieving data Record 34 of Set 2 | Kostomuksha
# Retrieving data Record 35 of Set 2 | Charagua
# Retrieving data Record 36 of Set 2 | Deputatskiy
# Retrieving data Record 37 of Set 2 | Attawapiskat
# City data not found, skipping...
# Retrieving data Record 38 of Set 2 | Jamestown
# Retrieving data Record 39 of Set 2 | Aklavik
# Retrieving data Record 40 of Set 2 | Mollendo
# Retrieving data Record 41 of Set 2 | Saryshagan
# City data not found, skipping...
# Retrieving data Record 42 of Set 2 | Lucea
# Retrieving data Record 43 of Set 2 | Severo-Kurilsk
# Retrieving data Record 44 of Set 2 | Harper
# Retrieving data Record 45 of Set 2 | Pombia
# Retrieving data Record 46 of Set 2 | Qaanaaq
# Retrieving data Record 47 of Set 2 | Blackwater
# Retrieving data Record 48 of Set 2 | Grand River South East
# City data not found, skipping...
# Retrieving data Record 49 of Set 2 | Port Alfred
# Retrieving data Record 50 of Set 2 | Vetluzhskiy
# Waiting 1 minute to start new set
# Retrieving data Record 1 of Set 3 | Kirovsk
# Retrieving data Record 2 of Set 3 | Airai
# Retrieving data Record 3 of Set 3 | Bandarbeyla
# Retrieving data Record 4 of Set 3 | Tumannyy
# City data not found, skipping...
# Retrieving data Record 5 of Set 3 | Souris
# Retrieving data Record 6 of Set 3 | Salinas
# Retrieving data Record 7 of Set 3 | Khatanga
# Retrieving data Record 8 of Set 3 | Bredasdorp
# Retrieving data Record 9 of Set 3 | Tura
# Retrieving data Record 10 of Set 3 | Inirida
# Retrieving data Record 11 of Set 3 | Nhulunbuy
# Retrieving data Record 12 of Set 3 | Illoqqortoormiut
# City data not found, skipping...
# Retrieving data Record 13 of Set 3 | Arcata
# Retrieving data Record 14 of Set 3 | Sijunjung
# Retrieving data Record 15 of Set 3 | Arica
# Retrieving data Record 16 of Set 3 | Savalou
# Retrieving data Record 17 of Set 3 | San Patricio
# Retrieving data Record 18 of Set 3 | Belushya Guba
# City data not found, skipping...
# Retrieving data Record 19 of Set 3 | Carnarvon
# Retrieving data Record 20 of Set 3 | Calama
# Retrieving data Record 21 of Set 3 | Tombouctou
# Retrieving data Record 22 of Set 3 | Beira
# Retrieving data Record 23 of Set 3 | Cape Town
# Retrieving data Record 24 of Set 3 | Inhambane
# Retrieving data Record 25 of Set 3 | Bauchi
# Retrieving data Record 26 of Set 3 | Charlestown
# Retrieving data Record 27 of Set 3 | Topolobampo
# Retrieving data Record 28 of Set 3 | Tiarei
# Retrieving data Record 29 of Set 3 | Kodiak
# Retrieving data Record 30 of Set 3 | Cockburn Harbour
# City data not found, skipping...
# Retrieving data Record 31 of Set 3 | Dehra Dun
# Retrieving data Record 32 of Set 3 | Santa Isabel
# Retrieving data Record 33 of Set 3 | Mys Shmidta
# City data not found, skipping...
# Retrieving data Record 34 of Set 3 | Kinablangan
# Retrieving data Record 35 of Set 3 | Lompoc
# Retrieving data Record 36 of Set 3 | Impfondo
# Retrieving data Record 37 of Set 3 | Nome
# Retrieving data Record 38 of Set 3 | Swiecie
# Retrieving data Record 39 of Set 3 | Hommelvik
# Retrieving data Record 40 of Set 3 | Vaini
# Retrieving data Record 41 of Set 3 | Torbay
# Retrieving data Record 42 of Set 3 | Puerto Escondido
# Retrieving data Record 43 of Set 3 | Puerto Ayora
# Retrieving data Record 44 of Set 3 | Houma
# Retrieving data Record 45 of Set 3 | Thompson
# Retrieving data Record 46 of Set 3 | Sur
# Retrieving data Record 47 of Set 3 | Rock Springs
# Retrieving data Record 48 of Set 3 | Nicoya
# Retrieving data Record 49 of Set 3 | Kidal
# Retrieving data Record 50 of Set 3 | Morondava
# Waiting 1 minute to start new set
# Retrieving data Record 1 of Set 4 | Padang
# Retrieving data Record 2 of Set 4 | Progress
# Retrieving data Record 3 of Set 4 | Atar
# Retrieving data Record 4 of Set 4 | Narsaq
# Retrieving data Record 5 of Set 4 | Hithadhoo
# Retrieving data Record 6 of Set 4 | Necochea
# Retrieving data Record 7 of Set 4 | Tasiilaq
# Retrieving data Record 8 of Set 4 | Toba
# Retrieving data Record 9 of Set 4 | Los Llanos De Aridane
# Retrieving data Record 10 of Set 4 | Umm Durman
# City data not found, skipping...
# Retrieving data Record 11 of Set 4 | Kembe
# Retrieving data Record 12 of Set 4 | Yar-Sale
# Retrieving data Record 13 of Set 4 | Taolanaro
# City data not found, skipping...
# Retrieving data Record 14 of Set 4 | Uwayl
# City data not found, skipping...
# Retrieving data Record 15 of Set 4 | Kaliua
# Retrieving data Record 16 of Set 4 | Lichtenburg
# Retrieving data Record 17 of Set 4 | Bam
# Retrieving data Record 18 of Set 4 | Botwood
# Retrieving data Record 19 of Set 4 | Matara
# Retrieving data Record 20 of Set 4 | Coahuayana
# Retrieving data Record 21 of Set 4 | Luwingu
# Retrieving data Record 22 of Set 4 | Hasaki
# Retrieving data Record 23 of Set 4 | Hilo
# Retrieving data Record 24 of Set 4 | Barentsburg
# City data not found, skipping...
# Retrieving data Record 25 of Set 4 | Namibe
# Retrieving data Record 26 of Set 4 | Norman Wells
# Retrieving data Record 27 of Set 4 | Touros
# Retrieving data Record 28 of Set 4 | Pitimbu
# Retrieving data Record 29 of Set 4 | Mendahara
# City data not found, skipping...
# Retrieving data Record 30 of Set 4 | Vardo
# Retrieving data Record 31 of Set 4 | Ahuimanu
# Retrieving data Record 32 of Set 4 | Camacupa
# Retrieving data Record 33 of Set 4 | Kawalu
# Retrieving data Record 34 of Set 4 | Pevek
# Retrieving data Record 35 of Set 4 | Puerto Baquerizo Moreno
# Retrieving data Record 36 of Set 4 | Atuona
# Retrieving data Record 37 of Set 4 | Bambous Virieux
# Retrieving data Record 38 of Set 4 | Kampong Cham
# Retrieving data Record 39 of Set 4 | Marystown
# Retrieving data Record 40 of Set 4 | Asau
# Retrieving data Record 41 of Set 4 | Krasnyy Chikoy
# Retrieving data Record 42 of Set 4 | Saint-Philippe
# Retrieving data Record 43 of Set 4 | Cabo San Lucas
# Retrieving data Record 44 of Set 4 | Nouadhibou
# Retrieving data Record 45 of Set 4 | Nguiu
# City data not found, skipping...
# Retrieving data Record 46 of Set 4 | San Juan
# Retrieving data Record 47 of Set 4 | Klaksvik
# Retrieving data Record 48 of Set 4 | Georgetown
# Retrieving data Record 49 of Set 4 | Acapulco
# Retrieving data Record 50 of Set 4 | Takapau
# Waiting 1 minute to start new set
# Retrieving data Record 1 of Set 5 | Kysyl-Syr
# Retrieving data Record 2 of Set 5 | Hegang
# Retrieving data Record 3 of Set 5 | Tilichiki
# Retrieving data Record 4 of Set 5 | Tsihombe
# City data not found, skipping...
# Retrieving data Record 5 of Set 5 | Kaeo
# Retrieving data Record 6 of Set 5 | Humberto De Campos
# Retrieving data Record 7 of Set 5 | Ribeira Grande
# Retrieving data Record 8 of Set 5 | Popova
# Retrieving data Record 9 of Set 5 | Chapais
# Retrieving data Record 10 of Set 5 | Thinadhoo
# Retrieving data Record 11 of Set 5 | Castro
# Retrieving data Record 12 of Set 5 | Ambon
# Retrieving data Record 13 of Set 5 | Zhangjiakou
# Retrieving data Record 14 of Set 5 | Constanta
# Retrieving data Record 15 of Set 5 | Ahipara
# Retrieving data Record 16 of Set 5 | Altona
# Retrieving data Record 17 of Set 5 | Buraydah
# Retrieving data Record 18 of Set 5 | Souillac
# Retrieving data Record 19 of Set 5 | Nola
# Retrieving data Record 20 of Set 5 | Aykhal
# Retrieving data Record 21 of Set 5 | Sao Joao Da Barra
# Retrieving data Record 22 of Set 5 | Provideniya
# Retrieving data Record 23 of Set 5 | Mahadday Weyne
# City data not found, skipping...
# Retrieving data Record 24 of Set 5 | Anshun
# Retrieving data Record 25 of Set 5 | Nishihara
# Retrieving data Record 26 of Set 5 | Saskylakh
# Retrieving data Record 27 of Set 5 | Christchurch
# Retrieving data Record 28 of Set 5 | Ozinki
# Retrieving data Record 29 of Set 5 | Mirnyy
# Retrieving data Record 30 of Set 5 | Grand Centre
# City data not found, skipping...
# Retrieving data Record 31 of Set 5 | Liwale
# Retrieving data Record 32 of Set 5 | Tiksi
# Retrieving data Record 33 of Set 5 | Sentyabrskiy
# City data not found, skipping...
# Retrieving data Record 34 of Set 5 | Uri
# Retrieving data Record 35 of Set 5 | Ornskoldsvik
# Retrieving data Record 36 of Set 5 | Ukiah
# Retrieving data Record 37 of Set 5 | Talnakh
# Retrieving data Record 38 of Set 5 | Tezu
# Retrieving data Record 39 of Set 5 | Maningrida
# Retrieving data Record 40 of Set 5 | Privolzhye
# Retrieving data Record 41 of Set 5 | Bur Gabo
# City data not found, skipping...
# Retrieving data Record 42 of Set 5 | Cairns
# Retrieving data Record 43 of Set 5 | Kuntaur
# Retrieving data Record 44 of Set 5 | Sao Filipe
# Retrieving data Record 45 of Set 5 | Shitanjing
# Retrieving data Record 46 of Set 5 | Fevralsk
# City data not found, skipping...
# Retrieving data Record 47 of Set 5 | Cayenne
# Retrieving data Record 48 of Set 5 | Luderitz
# Retrieving data Record 49 of Set 5 | Kathmandu
# Retrieving data Record 50 of Set 5 | Yining
# Waiting 1 minute to start new set
# Retrieving data Record 1 of Set 6 | North Las Vegas
# Retrieving data Record 2 of Set 6 | Yumen
# Retrieving data Record 3 of Set 6 | Port Hardy
# Retrieving data Record 4 of Set 6 | Bonavista
# Retrieving data Record 5 of Set 6 | Port Blair
# Retrieving data Record 6 of Set 6 | Limbang
# Retrieving data Record 7 of Set 6 | Fort Nelson
# Retrieving data Record 8 of Set 6 | Warmbad
# Retrieving data Record 9 of Set 6 | Meulaboh
# Retrieving data Record 10 of Set 6 | Lubango
# Retrieving data Record 11 of Set 6 | Port Shepstone
# Retrieving data Record 12 of Set 6 | Arkhangelos
# City data not found, skipping...
# Retrieving data Record 13 of Set 6 | Ulladulla
# Retrieving data Record 14 of Set 6 | Ketchenery
# City data not found, skipping...
# Retrieving data Record 15 of Set 6 | Ust-Kamchatsk
# City data not found, skipping...
# Retrieving data Record 16 of Set 6 | Vaitupu
# City data not found, skipping...
# Retrieving data Record 17 of Set 6 | Shirokiy
# Retrieving data Record 18 of Set 6 | Ponta Do Sol
# Retrieving data Record 19 of Set 6 | Bonthe
# Retrieving data Record 20 of Set 6 | Lavrentiya
# Retrieving data Record 21 of Set 6 | Banepa
# Retrieving data Record 22 of Set 6 | Sabang
# Retrieving data Record 23 of Set 6 | Lotofaga
# Retrieving data Record 24 of Set 6 | Abbeville
# Retrieving data Record 25 of Set 6 | Havelock
# Retrieving data Record 26 of Set 6 | Urengoy
# Retrieving data Record 27 of Set 6 | Vila Praia De Ancora
# Retrieving data Record 28 of Set 6 | Vuktyl
# Retrieving data Record 29 of Set 6 | Dunedin
# Retrieving data Record 30 of Set 6 | Juneau
# Retrieving data Record 31 of Set 6 | Stanger
# Retrieving data Record 32 of Set 6 | Kudahuvadhoo
# Retrieving data Record 33 of Set 6 | Bengkulu
# Retrieving data Record 34 of Set 6 | Petropavlovsk-Kamchatskiy
# Retrieving data Record 35 of Set 6 | Vallenar
# Retrieving data Record 36 of Set 6 | Pontianak
# Retrieving data Record 37 of Set 6 | Cidreira
# Retrieving data Record 38 of Set 6 | Likhoslavl
# Retrieving data Record 39 of Set 6 | Bluefield
# Retrieving data Record 40 of Set 6 | Esperance
# Retrieving data Record 41 of Set 6 | Phan Thiet
# Retrieving data Record 42 of Set 6 | Kramat
# Retrieving data Record 43 of Set 6 | Aflu
# City data not found, skipping...
# Retrieving data Record 44 of Set 6 | Goure
# Retrieving data Record 45 of Set 6 | Komsomolskiy
# Retrieving data Record 46 of Set 6 | Vestmannaeyjar
# Retrieving data Record 47 of Set 6 | Jutai
# Retrieving data Record 48 of Set 6 | Swan River
# Retrieving data Record 49 of Set 6 | Salalah
# Retrieving data Record 50 of Set 6 | Sabha
# Waiting 1 minute to start new set
# Retrieving data Record 1 of Set 7 | Cabinda
# Retrieving data Record 2 of Set 7 | Mehamn
# Retrieving data Record 3 of Set 7 | Paamiut
# Retrieving data Record 4 of Set 7 | Grand Gaube
# Retrieving data Record 5 of Set 7 | Gasa
# Retrieving data Record 6 of Set 7 | General Roca
# Retrieving data Record 7 of Set 7 | Mogadishu
# Retrieving data Record 8 of Set 7 | Pocone
# Retrieving data Record 9 of Set 7 | Sitka
# Retrieving data Record 10 of Set 7 | Shancheng
# Retrieving data Record 11 of Set 7 | Qaqortoq
# Retrieving data Record 12 of Set 7 | College
# Retrieving data Record 13 of Set 7 | Mooi River
# City data not found, skipping...
# Retrieving data Record 14 of Set 7 | Marfino
# Retrieving data Record 15 of Set 7 | Lasa
# Retrieving data Record 16 of Set 7 | Ribeirao Branco
# Retrieving data Record 17 of Set 7 | Falealupo
# City data not found, skipping...
# Retrieving data Record 18 of Set 7 | Yarada
# Retrieving data Record 19 of Set 7 | Mount Isa
# Retrieving data Record 20 of Set 7 | Lagoa
# Retrieving data Record 21 of Set 7 | Jiazi
# Retrieving data Record 22 of Set 7 | Victor Harbor
# Retrieving data Record 23 of Set 7 | Bathsheba
# Retrieving data Record 24 of Set 7 | Coihaique
# Retrieving data Record 25 of Set 7 | Saint George
# Retrieving data Record 26 of Set 7 | Pingdingshan
# Retrieving data Record 27 of Set 7 | Tuatapere
# Retrieving data Record 28 of Set 7 | Jobner
# Retrieving data Record 29 of Set 7 | Abashiri
# Retrieving data Record 30 of Set 7 | Upernavik
# Retrieving data Record 31 of Set 7 | Ostrovnoy
# Retrieving data Record 32 of Set 7 | Itirucu
# Retrieving data Record 33 of Set 7 | Serowe
# Retrieving data Record 34 of Set 7 | Valence
# Retrieving data Record 35 of Set 7 | Leua
# Retrieving data Record 36 of Set 7 | Ust-Tsilma
# Retrieving data Record 37 of Set 7 | Gat
# Retrieving data Record 38 of Set 7 | San Cristobal
# Retrieving data Record 39 of Set 7 | Zuenoula
# Retrieving data Record 40 of Set 7 | Pemba
# Retrieving data Record 41 of Set 7 | Rock Sound
# Retrieving data Record 42 of Set 7 | Phan Rang
# City data not found, skipping...
# Retrieving data Record 43 of Set 7 | Mendi
# Retrieving data Record 44 of Set 7 | Bradley
# Retrieving data Record 45 of Set 7 | Mus
# Retrieving data Record 46 of Set 7 | Palmas Bellas
# Retrieving data Record 47 of Set 7 | Lima
# Retrieving data Record 48 of Set 7 | Tolbazy
# Retrieving data Record 49 of Set 7 | Caravelas
# Retrieving data Record 50 of Set 7 | Auray
# Waiting 1 minute to start new set
# Retrieving data Record 1 of Set 8 | Kapit
# Retrieving data Record 2 of Set 8 | Shibarghan
# City data not found, skipping...
# Retrieving data Record 3 of Set 8 | Port-Gentil
# Retrieving data Record 4 of Set 8 | Asopos
# Retrieving data Record 5 of Set 8 | Kemijarvi
# Retrieving data Record 6 of Set 8 | Calvia
# Retrieving data Record 7 of Set 8 | Pimentel
# Retrieving data Record 8 of Set 8 | Redding
# Retrieving data Record 9 of Set 8 | Filadelfia
# Retrieving data Record 10 of Set 8 | Saint-Joseph
# Retrieving data Record 11 of Set 8 | Wanning
# Retrieving data Record 12 of Set 8 | Makakilo City
# Retrieving data Record 13 of Set 8 | Timbakion
# City data not found, skipping...
# Retrieving data Record 14 of Set 8 | Gomez Plata
# Retrieving data Record 15 of Set 8 | Tabuk
# Retrieving data Record 16 of Set 8 | Urdzhar
# City data not found, skipping...
# Retrieving data Record 17 of Set 8 | Surt
# Retrieving data Record 18 of Set 8 | Edmundston
# Retrieving data Record 19 of Set 8 | Louny
# Retrieving data Record 20 of Set 8 | Saleaula
# City data not found, skipping...
# Retrieving data Record 21 of Set 8 | Grindavik
# Retrieving data Record 22 of Set 8 | Honiara
# Retrieving data Record 23 of Set 8 | Mountain Home
# Retrieving data Record 24 of Set 8 | Arkadelphia
# Retrieving data Record 25 of Set 8 | Ciudad Bolivar
# Retrieving data Record 26 of Set 8 | Pilar
# Retrieving data Record 27 of Set 8 | Sao Miguel Do Araguaia
# Retrieving data Record 28 of Set 8 | Broken Hill
# Retrieving data Record 29 of Set 8 | Kiruna
# Retrieving data Record 30 of Set 8 | Kibala
# Retrieving data Record 31 of Set 8 | Dergachi
# Retrieving data Record 32 of Set 8 | Altamont
# Retrieving data Record 33 of Set 8 | Hamilton
# Retrieving data Record 34 of Set 8 | Hobara
# Retrieving data Record 35 of Set 8 | Poum
# Retrieving data Record 36 of Set 8 | Neuquen
# Retrieving data Record 37 of Set 8 | Huaral
# Retrieving data Record 38 of Set 8 | Chuy
# Retrieving data Record 39 of Set 8 | Bolungarvik
# City data not found, skipping...
# Retrieving data Record 40 of Set 8 | Rio Gallegos
# Retrieving data Record 41 of Set 8 | Ishigaki
# Retrieving data Record 42 of Set 8 | Beringovskiy
# Retrieving data Record 43 of Set 8 | Kiunga
# Retrieving data Record 44 of Set 8 | Sioux Lookout
# Retrieving data Record 45 of Set 8 | Ilulissat
# Retrieving data Record 46 of Set 8 | Horqueta
# Retrieving data Record 47 of Set 8 | Roma
# Retrieving data Record 48 of Set 8 | Anadyr
# Retrieving data Record 49 of Set 8 | Adela
# Retrieving data Record 50 of Set 8 | Clyde River
# Waiting 1 minute to start new set
# Retrieving data Record 1 of Set 9 | Malakal
# Retrieving data Record 2 of Set 9 | Haines Junction
# Retrieving data Record 3 of Set 9 | Devarkonda
# Retrieving data Record 4 of Set 9 | Phalodi
# Retrieving data Record 5 of Set 9 | Pallasovka
# Retrieving data Record 6 of Set 9 | Rocha
# Retrieving data Record 7 of Set 9 | Veraval
# Retrieving data Record 8 of Set 9 | Qasigiannguit
# Retrieving data Record 9 of Set 9 | Tongliao
# Retrieving data Record 10 of Set 9 | New Glasgow
# Retrieving data Record 11 of Set 9 | Lipari
# Retrieving data Record 12 of Set 9 | Berdigestyakh
# Retrieving data Record 13 of Set 9 | Taoudenni
# Retrieving data Record 14 of Set 9 | Ambilobe
# Retrieving data Record 15 of Set 9 | Ust-Nera
# Retrieving data Record 16 of Set 9 | Pokrovka
# Retrieving data Record 17 of Set 9 | Muli
# Retrieving data Record 18 of Set 9 | Mecca
# Retrieving data Record 19 of Set 9 | Kodinsk
# Retrieving data Record 20 of Set 9 | Leh
# Retrieving data Record 21 of Set 9 | Te Anau
# Retrieving data Record 22 of Set 9 | Victoria
# Retrieving data Record 23 of Set 9 | Portland
# Retrieving data Record 24 of Set 9 | Tromso
# Retrieving data Record 25 of Set 9 | Windsor
# Retrieving data Record 26 of Set 9 | Khanpur
# Retrieving data Record 27 of Set 9 | Olafsvik
# Retrieving data Record 28 of Set 9 | Mildura
# Retrieving data Record 29 of Set 9 | Cururupu
# Retrieving data Record 30 of Set 9 | Vilhena
# Retrieving data Record 31 of Set 9 | Russell
# Retrieving data Record 32 of Set 9 | Samusu
# City data not found, skipping...
# Retrieving data Record 33 of Set 9 | Beaverlodge
# Retrieving data Record 34 of Set 9 | Sakakah
# Retrieving data Record 35 of Set 9 | Xining
# Retrieving data Record 36 of Set 9 | Tocopilla
# Retrieving data Record 37 of Set 9 | Pisco
# Retrieving data Record 38 of Set 9 | Sapao
# City data not found, skipping...
# Retrieving data Record 39 of Set 9 | Progreso
# Retrieving data Record 40 of Set 9 | Mae Sai
# Retrieving data Record 41 of Set 9 | Zhigansk
# Retrieving data Record 42 of Set 9 | Hue
# Retrieving data Record 43 of Set 9 | Topchikha
# Retrieving data Record 44 of Set 9 | Ridgecrest
# Retrieving data Record 45 of Set 9 | Olinda
# Retrieving data Record 46 of Set 9 | Lolua
# City data not found, skipping...
# Retrieving data Record 47 of Set 9 | Fare
# Retrieving data Record 48 of Set 9 | Pundaguitan
# Retrieving data Record 49 of Set 9 | Phonhong
# Retrieving data Record 50 of Set 9 | Port Lincoln
# Waiting 1 minute to start new set
# Retrieving data Record 1 of Set 10 | Bethel
# Retrieving data Record 2 of Set 10 | Aleksandrovskoye
# Retrieving data Record 3 of Set 10 | Barcarena
# Retrieving data Record 4 of Set 10 | Cap Malheureux
# Retrieving data Record 5 of Set 10 | Oranjemund
# Retrieving data Record 6 of Set 10 | Nagato
# Retrieving data Record 7 of Set 10 | Muriwai Beach
# Retrieving data Record 8 of Set 10 | Salta
# Retrieving data Record 9 of Set 10 | Alofi
# Retrieving data Record 10 of Set 10 | Jimenez
# Retrieving data Record 11 of Set 10 | Kajaani
# Retrieving data Record 12 of Set 10 | Banda Aceh
# Retrieving data Record 13 of Set 10 | Bati
# Retrieving data Record 14 of Set 10 | Agadez
# Retrieving data Record 15 of Set 10 | Umzimvubu
# City data not found, skipping...
# Retrieving data Record 16 of Set 10 | Athabasca
# Retrieving data Record 17 of Set 10 | Saldanha
# Retrieving data Record 18 of Set 10 | Salinopolis
# Retrieving data Record 19 of Set 10 | Adrar
# Retrieving data Record 20 of Set 10 | Nong Khai
# Retrieving data Record 21 of Set 10 | Ballina
# Retrieving data Record 22 of Set 10 | Sola
# Retrieving data Record 23 of Set 10 | Hailey
# Retrieving data Record 24 of Set 10 | Umm Kaddadah
# Retrieving data Record 25 of Set 10 | Sanford
# Retrieving data Record 26 of Set 10 | Bonito
# Retrieving data Record 27 of Set 10 | Deep River
# Retrieving data Record 28 of Set 10 | Qui Nhon
# Retrieving data Record 29 of Set 10 | Karratha
# Retrieving data Record 30 of Set 10 | Avera
# Retrieving data Record 31 of Set 10 | Kendari
# Retrieving data Record 32 of Set 10 | Rupert
# Retrieving data Record 33 of Set 10 | Hambantota
# Retrieving data Record 34 of Set 10 | Lincoln
# Retrieving data Record 35 of Set 10 | Kandrian
# Retrieving data Record 36 of Set 10 | Kahului
# Retrieving data Record 37 of Set 10 | Pathein
# Retrieving data Record 38 of Set 10 | Cozumel
# Retrieving data Record 39 of Set 10 | Kavaratti
# Retrieving data Record 40 of Set 10 | Wencheng
# Retrieving data Record 41 of Set 10 | Bridgewater
# Retrieving data Record 42 of Set 10 | Narasannapeta
# Retrieving data Record 43 of Set 10 | Dzhusaly
# City data not found, skipping...
# Retrieving data Record 44 of Set 10 | Chignahuapan
# Retrieving data Record 45 of Set 10 | Santa Rosa
# Retrieving data Record 46 of Set 10 | Naze
# Retrieving data Record 47 of Set 10 | Korla
# Retrieving data Record 48 of Set 10 | San Rafael Del Sur
# Retrieving data Record 49 of Set 10 | Canavieiras
# Retrieving data Record 50 of Set 10 | Temerloh
# Waiting 1 minute to start new set
# Retrieving data Record 1 of Set 11 | Hohhot
# Retrieving data Record 2 of Set 11 | Tsaratanana
# Retrieving data Record 3 of Set 11 | Acajutla
# Retrieving data Record 4 of Set 11 | Polyarnyy
# Retrieving data Record 5 of Set 11 | Kirakira
# Retrieving data Record 6 of Set 11 | Aswan
# Retrieving data Record 7 of Set 11 | Straumen
# Retrieving data Record 8 of Set 11 | Manggar
# Retrieving data Record 9 of Set 11 | Longlac
# City data not found, skipping...
# Retrieving data Record 10 of Set 11 | Wilmington
# Retrieving data Record 11 of Set 11 | Rognan
# Retrieving data Record 12 of Set 11 | Ngaoundere
# Retrieving data Record 13 of Set 11 | Montepuez
# Retrieving data Record 14 of Set 11 | Gallipoli
# Retrieving data Record 15 of Set 11 | Olden
# Retrieving data Record 16 of Set 11 | Westport
# Retrieving data Record 17 of Set 11 | Prado
# Retrieving data Record 18 of Set 11 | Barao De Melgaco
# Retrieving data Record 19 of Set 11 | Pankrushikha
# Retrieving data Record 20 of Set 11 | Yeppoon
# Retrieving data Record 21 of Set 11 | Gravdal
# Retrieving data Record 22 of Set 11 | Flin Flon
# Retrieving data Record 23 of Set 11 | Payo
# Retrieving data Record 24 of Set 11 | Abu Dhabi
# Retrieving data Record 25 of Set 11 | Mandalgovi
# Retrieving data Record 26 of Set 11 | Goksun
# Retrieving data Record 27 of Set 11 | Wanaka
# Retrieving data Record 28 of Set 11 | Pangnirtung
# Retrieving data Record 29 of Set 11 | Lulea
# Retrieving data Record 30 of Set 11 | Paradwip
# City data not found, skipping...
# Retrieving data Record 31 of Set 11 | Saint Anthony
# Retrieving data Record 32 of Set 11 | Putla
# City data not found, skipping...
# Retrieving data Record 33 of Set 11 | Rahimatpur
# Retrieving data Record 34 of Set 11 | Chalmette
# Retrieving data Record 35 of Set 11 | Kaduqli
# Retrieving data Record 36 of Set 11 | Miraflores
# Retrieving data Record 37 of Set 11 | Bar Harbor
# Retrieving data Record 38 of Set 11 | Seda
# Retrieving data Record 39 of Set 11 | Pochutla
# Retrieving data Record 40 of Set 11 | Kalmunai
# Retrieving data Record 41 of Set 11 | Nichinan
# Retrieving data Record 42 of Set 11 | Ulaanbaatar
# Retrieving data Record 43 of Set 11 | Paramonga
# Retrieving data Record 44 of Set 11 | Longyearbyen
# Retrieving data Record 45 of Set 11 | Hay River
# Retrieving data Record 46 of Set 11 | Tessalit
# Retrieving data Record 47 of Set 11 | Kurtalan
# Retrieving data Record 48 of Set 11 | Tautira
# Retrieving data Record 49 of Set 11 | Nantucket
# Retrieving data Record 50 of Set 11 | Lantawan
# Waiting 1 minute to start new set
# Retrieving data Record 1 of Set 12 | Yerofey Pavlovich
# Retrieving data Record 2 of Set 12 | Ordzhonikidze
# Retrieving data Record 3 of Set 12 | Dengzhou
# Retrieving data Record 4 of Set 12 | Wairoa
# Retrieving data Record 5 of Set 12 | At-Bashi
# Retrieving data Record 6 of Set 12 | Hermiston
# Retrieving data Record 7 of Set 12 | Halalo
# City data not found, skipping...
# Retrieving data Record 8 of Set 12 | Lhokseumawe
# Retrieving data Record 9 of Set 12 | Seydi
# Retrieving data Record 10 of Set 12 | Saint-Georges
# Retrieving data Record 11 of Set 12 | Karasjok
# Retrieving data Record 12 of Set 12 | Okhotsk
# Retrieving data Record 13 of Set 12 | Sungaipenuh
# Retrieving data Record 14 of Set 12 | Milingimbi
# City data not found, skipping...
# Retrieving data Record 15 of Set 12 | Kasongo-Lunda
# Retrieving data Record 16 of Set 12 | Santa Isabel Do Rio Negro
# Retrieving data Record 17 of Set 12 | Damietta
# Retrieving data Record 18 of Set 12 | Arlit
# Retrieving data Record 19 of Set 12 | Arroyo
# Retrieving data Record 20 of Set 12 | Dillon
# Retrieving data Record 21 of Set 12 | San Ignacio
# Retrieving data Record 22 of Set 12 | Iqaluit
# Retrieving data Record 23 of Set 12 | Dese
# Retrieving data Record 24 of Set 12 | Dobryanka
# Retrieving data Record 25 of Set 12 | Sfantu Gheorghe
# Retrieving data Record 26 of Set 12 | Trincomalee
# Retrieving data Record 27 of Set 12 | Rio Real
# Retrieving data Record 28 of Set 12 | Chala
# Retrieving data Record 29 of Set 12 | Goundi
# Retrieving data Record 30 of Set 12 | Camargo
# Retrieving data Record 31 of Set 12 | Muros
# Retrieving data Record 32 of Set 12 | Aitape
# Retrieving data Record 33 of Set 12 | Charters Towers
# Retrieving data Record 34 of Set 12 | La Ronge
# Retrieving data Record 35 of Set 12 | Jieshou
# Retrieving data Record 36 of Set 12 | Saryozek
# Retrieving data Record 37 of Set 12 | Gazli
# Retrieving data Record 38 of Set 12 | Nikki
# Retrieving data Record 39 of Set 12 | Tarko-Sale
# Retrieving data Record 40 of Set 12 | Cockburn Town
# Retrieving data Record 41 of Set 12 | Rioja
# Retrieving data Record 42 of Set 12 | Ginir
# Retrieving data Record 43 of Set 12 | Polunochnoye
# Retrieving data Record 44 of Set 12 | Tanabe
# Retrieving data Record 45 of Set 12 | Faya
# Retrieving data Record 46 of Set 12 | Port-Cartier
# Retrieving data Record 47 of Set 12 | Erzin
# Retrieving data Record 48 of Set 12 | Sorong
# Retrieving data Record 49 of Set 12 | Guiratinga
# Retrieving data Record 50 of Set 12 | Poltavka
# Waiting 1 minute to start new set
# Retrieving data Record 1 of Set 13 | Goderich
# Retrieving data Record 2 of Set 13 | Black River
# Retrieving data Record 3 of Set 13 | Razole
# Retrieving data Record 4 of Set 13 | Belmonte
# Retrieving data Record 5 of Set 13 | Itapira
# Retrieving data Record 6 of Set 13 | Tabukiniberu
# City data not found, skipping...
# Retrieving data Record 7 of Set 13 | Ouesso
# Retrieving data Record 8 of Set 13 | Kungurtug
# Retrieving data Record 9 of Set 13 | Jiwani
# Retrieving data Record 10 of Set 13 | Praia Da Vitoria
# Retrieving data Record 11 of Set 13 | Shimoda
# Retrieving data Record 12 of Set 13 | Soresina
# Retrieving data Record 13 of Set 13 | Eydhafushi
# Retrieving data Record 14 of Set 13 | Piacabucu
# Retrieving data Record 15 of Set 13 | Kyzyl-Suu
# Retrieving data Record 16 of Set 13 | Asahikawa
# Retrieving data Record 17 of Set 13 | Strezhevoy
# Retrieving data Record 18 of Set 13 | Pemberton
# Retrieving data Record 19 of Set 13 | Whitehorse
# Retrieving data Record 20 of Set 13 | Uni
# Retrieving data Record 21 of Set 13 | Najran
# Retrieving data Record 22 of Set 13 | Terrace
# Retrieving data Record 23 of Set 13 | Itupiranga
# Retrieving data Record 24 of Set 13 | Tres Arroyos
# Retrieving data Record 25 of Set 13 | Zaragoza
# Retrieving data Record 26 of Set 13 | Lorengau
# Retrieving data Record 27 of Set 13 | Matagami
# Retrieving data Record 28 of Set 13 | Kasaragod
# Retrieving data Record 29 of Set 13 | Talcahuano
# Retrieving data Record 30 of Set 13 | Kambove
# Retrieving data Record 31 of Set 13 | Tam Ky
# Retrieving data Record 32 of Set 13 | Chanika
# Retrieving data Record 33 of Set 13 | Maceio
# Retrieving data Record 34 of Set 13 | Kolosovka
# Retrieving data Record 35 of Set 13 | Sambava
# Retrieving data Record 36 of Set 13 | San Andres
# Retrieving data Record 37 of Set 13 | Chirilagua
# Retrieving data Record 38 of Set 13 | Ponta Delgada
# Retrieving data Record 39 of Set 13 | Kuche
# City data not found, skipping...
# Retrieving data Record 40 of Set 13 | Letterkenny
# Retrieving data Record 41 of Set 13 | Izhma
# Retrieving data Record 42 of Set 13 | Yarmouth
# Retrieving data Record 43 of Set 13 | Wexford
# Retrieving data Record 44 of Set 13 | Senno
# Retrieving data Record 45 of Set 13 | Koubia
# Retrieving data Record 46 of Set 13 | Vao
# Retrieving data Record 47 of Set 13 | Balkanabat
# Retrieving data Record 48 of Set 13 | Sosnovo-Ozerskoye
# Retrieving data Record 49 of Set 13 | Kamaishi
# Retrieving data Record 50 of Set 13 | Zhenlai
# Waiting 1 minute to start new set
# Retrieving data Record 1 of Set 14 | Primore
# City data not found, skipping...
# Retrieving data Record 2 of Set 14 | Port Hedland
# Retrieving data Record 3 of Set 14 | Jabiru
# City data not found, skipping...
# Retrieving data Record 4 of Set 14 | Channel-Port Aux Basques
# Retrieving data Record 5 of Set 14 | Palmer
# Retrieving data Record 6 of Set 14 | Brae
# Retrieving data Record 7 of Set 14 | Kamenskoye
# City data not found, skipping...
# Retrieving data Record 8 of Set 14 | Bonham
# Retrieving data Record 9 of Set 14 | Zachary
# Retrieving data Record 10 of Set 14 | Pozoblanco
# Retrieving data Record 11 of Set 14 | Cabedelo
# Retrieving data Record 12 of Set 14 | Isangel
# Retrieving data Record 13 of Set 14 | Boddam
# Retrieving data Record 14 of Set 14 | Coari
# Retrieving data Record 15 of Set 14 | Martigny
# Retrieving data Record 16 of Set 14 | Mersin
# Retrieving data Record 17 of Set 14 | Pauini
# Retrieving data Record 18 of Set 14 | Safwah
# City data not found, skipping...
# Retrieving data Record 19 of Set 14 | Vestmanna
# Retrieving data Record 20 of Set 14 | Sumbawa
# City data not found, skipping...
# Retrieving data Record 21 of Set 14 | Wahran
# City data not found, skipping...
# Retrieving data Record 22 of Set 14 | Mendrisio
# Retrieving data Record 23 of Set 14 | Rabaul
# Retrieving data Record 24 of Set 14 | Pustoshka
# Retrieving data Record 25 of Set 14 | Bhadrachalam
# Retrieving data Record 26 of Set 14 | Ibipeba
# Retrieving data Record 27 of Set 14 | Richards Bay
# Retrieving data Record 28 of Set 14 | Gumdag
# Retrieving data Record 29 of Set 14 | Yulara
# Retrieving data Record 30 of Set 14 | Coquimbo
# Retrieving data Record 31 of Set 14 | Pella
# Retrieving data Record 32 of Set 14 | Pangoa
# Retrieving data Record 33 of Set 14 | Wenling
# Retrieving data Record 34 of Set 14 | Quatre Cocos
# Retrieving data Record 35 of Set 14 | Collie
# Retrieving data Record 36 of Set 14 | Panama City
# Retrieving data Record 37 of Set 14 | Egvekinot
# Retrieving data Record 38 of Set 14 | Ende
# Retrieving data Record 39 of Set 14 | Rumphi
# Retrieving data Record 40 of Set 14 | Sao Jose Da Coroa Grande
# Retrieving data Record 41 of Set 14 | Afanasyevo
# City data not found, skipping...
# Retrieving data Record 42 of Set 14 | Biltine
# Retrieving data Record 43 of Set 14 | Shubarshi
# Retrieving data Record 44 of Set 14 | Synya
# Retrieving data Record 45 of Set 14 | Crotone
# Retrieving data Record 46 of Set 14 | Goulburn
# Retrieving data Record 47 of Set 14 | Zabinka
# City data not found, skipping...
# Retrieving data Record 48 of Set 14 | Manta
# Retrieving data Record 49 of Set 14 | Valleyview
# Retrieving data Record 50 of Set 14 | Presidencia Roque Saenz Pena
# Waiting 1 minute to start new set
# Retrieving data Record 1 of Set 15 | Xuddur
# Retrieving data Record 2 of Set 15 | Usinsk
# Retrieving data Record 3 of Set 15 | Saiha
# Retrieving data Record 4 of Set 15 | Prainha
# Retrieving data Record 5 of Set 15 | Bouza
# Retrieving data Record 6 of Set 15 | Bandiagara
# Retrieving data Record 7 of Set 15 | Abu Zabad
# Retrieving data Record 8 of Set 15 | Nalut
# Retrieving data Record 9 of Set 15 | Rungata
# City data not found, skipping...
# Retrieving data Record 10 of Set 15 | Madingou
# Retrieving data Record 11 of Set 15 | Vila Franca Do Campo
# Retrieving data Record 12 of Set 15 | Qena
# Retrieving data Record 13 of Set 15 | Terrace Bay
# Retrieving data Record 14 of Set 15 | Viedma
# Retrieving data Record 15 of Set 15 | Santa Cruz
# Retrieving data Record 16 of Set 15 | Monte Alegre
# Retrieving data Record 17 of Set 15 | Aljezur
# Retrieving data Record 18 of Set 15 | Chagda
# City data not found, skipping...
# Retrieving data Record 19 of Set 15 | Bad Hofgastein
# Retrieving data Record 20 of Set 15 | Tatawin
# Retrieving data Record 21 of Set 15 | Alotau
# City data not found, skipping...
# Retrieving data Record 22 of Set 15 | Luxor
# Retrieving data Record 23 of Set 15 | Eureka
# Retrieving data Record 24 of Set 15 | Port Macquarie
# Retrieving data Record 25 of Set 15 | Pozo Colorado
# Retrieving data Record 26 of Set 15 | Sao Joaquim
# Retrieving data Record 27 of Set 15 | Olga
# Retrieving data Record 28 of Set 15 | Datong
# Retrieving data Record 29 of Set 15 | Esmeralda
# Retrieving data Record 30 of Set 15 | Mareeba
# Retrieving data Record 31 of Set 15 | Fairbanks
# Retrieving data Record 32 of Set 15 | Stromness
# Retrieving data Record 33 of Set 15 | Yuryevets
# Retrieving data Record 34 of Set 15 | Agirish
# Retrieving data Record 35 of Set 15 | Kabin Buri
# Retrieving data Record 36 of Set 15 | Guangshui
# Retrieving data Record 37 of Set 15 | Marsh Harbour
# Retrieving data Record 38 of Set 15 | Camacha
# Retrieving data Record 39 of Set 15 | Altay
# Retrieving data Record 40 of Set 15 | Killybegs
# Retrieving data Record 41 of Set 15 | Mnogovershinnyy
# Retrieving data Record 42 of Set 15 | Imeni Poliny Osipenko
# Retrieving data Record 43 of Set 15 | Laguna
# Retrieving data Record 44 of Set 15 | Piltene
# -----------------------------
# Finished City Data Detrieval Process
# -----------------------------

# %%
# Add the data to a new DataFrame
city_data_df = pd.DataFrame(cities_data)
city_data_df.tail(2)
# Out:
#         City Country  Latitude  Longitude  Max Temperature  Percent Humidity  \
# 684   Laguna      US   38.4210  -121.4238            58.01                58
# 685  Piltene      LV   57.2243    21.6744            42.75                61
#
#      Percent Cloudiness  Wind Speed Weather Description
# 684                   0       12.66           clear sky
# 685                   0       16.11           clear sky

# %%
# Export as csv file
city_data_df.to_csv("Weather_Database/WeatherPy_Database.csv", index_label="City_ID")
