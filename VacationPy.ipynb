# %%
# Import Dependencies
import pandas as pd
import gmaps
import requests

# Import the API key
from config import g_key

# %%
# Read the CSV you saved from WeatherPY.ipynb into a DF
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID          City Country                 Date      Lat       Lng  \
# 0        0     Upernavik      GL  2022-04-25 03:19:29  72.7868  -56.1549
# 1        1         Sitka      US  2022-04-25 03:21:21  57.0531 -135.3300
# 2        2       Ushuaia      AR  2022-04-25 03:18:12 -54.8000  -68.3000
# 3        3  Punta Arenas      CL  2022-04-25 03:22:13 -53.1500  -70.9167
# 4        4       Mataura      NZ  2022-04-25 03:18:13 -46.1927  168.8643
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     -0.54        88          42        6.49
# 1     46.29        76          75        9.22
# 2     37.06        81           0        5.75
# 3     42.91        87         100       10.36
# 4     53.47        82          92       12.86

# %%
# use dtypes to check data types of df.  mapping data MUST be integer or float
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Tell gmaps to use API key
gmaps.configure(api_key=g_key)

# %%
# Convert negative temps to positive (temps must be non-negative for heatmap_layer line of code!)
max_temp = city_data_df["Max Temp"]
city_data_df["Max Temp"] = pd.Series([0 if i < 0 else i for i in max_temp])

# or max_temp = [max(temp, 0) for temp in city_data_df["Max Temp"]],
# If two or more positional arguments are provided, the largest of the positional arguments is returned.

# Get the maximum temperature non-negative (mod code)
# temps = []
# for temp in max_temp:
#     temps.append(max(temp, 0))

# %%
city_data_df.head()
# Out:
#    City_ID          City Country                 Date      Lat       Lng  \
# 0        0     Upernavik      GL  2022-04-25 03:19:29  72.7868  -56.1549
# 1        1         Sitka      US  2022-04-25 03:21:21  57.0531 -135.3300
# 2        2       Ushuaia      AR  2022-04-25 03:18:12 -54.8000  -68.3000
# 3        3  Punta Arenas      CL  2022-04-25 03:22:13 -53.1500  -70.9167
# 4        4       Mataura      NZ  2022-04-25 03:18:13 -46.1927  168.8643
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0      0.00        88          42        6.49
# 1     46.29        76          75        9.22
# 2     37.06        81           0        5.75
# 3     42.91        87         100       10.36
# 4     53.47        82          92       12.86

# %%
# Create HEATMAP for MAXIMUM TEMPERATURE

#1. Assign the locations to an array of latitude and longitude pairs
locations = city_data_df[["Lat", "Lng"]] # [latitude, longitude]
#2. Assign the weights variable to some values
temperatures = city_data_df["Max Temp"] # an array of lengh equal to the locations array length
#3. Assign the figure variable to the gmaps.figure() attribute
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
#4. Assign the heatmap_layer variable to the heatmap_layer attribute and add in the locations
heatmap_layer = gmaps.heatmap_layer(locations, weights=temperatures, dissipating=False)
# heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp])

heatmap_layer.max_intensity=300
heatmap_layer.point_radius=4
# could have passed next to dissipating in above step 4

#5 Add the heatmap layer
fig.add_layer(heatmap_layer)
#6. Call the figure to plot the data
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Create HEATMAP for HUMIDITY

# Heatmap for percent humidity
locations = city_data_df[['Lat', 'Lng']]
humidity = city_data_df['Humidity']
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
#Call the figure to plot the data
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Create HEATMAP for CLOUDINESS

# Heatmap for percent cloudiness
locations = city_data_df[['Lat', 'Lng']]
clouds = city_data_df['Cloudiness']
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
#Call the figure to plot the data
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Create HEATMAP for WIND SPEED

# Heatmap for wind speed
locations = city_data_df[['Lat', 'Lng']]
wind = city_data_df['Wind Speed']
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=wind, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
#Call the figure to plot the data
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Get VACATION CRITERIA

# %%
# Ask the customer to add a minimum and maximum temperature value.  must be FLOAT, convert to float
min_temp = float(input("What is the minimum maximum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum maximum temperature you would like for your trip? 35
# What is the maximum temperature you would like for your trip? 80

# %%
# Filter the MAX TEMP column in city_data_df to create a new df with cities that meet input criteria
preferred_cities_df = city_data_df.loc[(city_data_df['Max Temp'] <= max_temp) & (city_data_df['Max Temp'] >= min_temp)]
preferred_cities_df.head()
# Out:
#    City_ID          City Country                 Date      Lat       Lng  \
# 1        1         Sitka      US  2022-04-25 03:21:21  57.0531 -135.3300
# 2        2       Ushuaia      AR  2022-04-25 03:18:12 -54.8000  -68.3000
# 3        3  Punta Arenas      CL  2022-04-25 03:22:13 -53.1500  -70.9167
# 4        4       Mataura      NZ  2022-04-25 03:18:13 -46.1927  168.8643
# 5        5   Port Alfred      ZA  2022-04-25 03:22:13 -33.5906   26.8910
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 1     46.29        76          75        9.22
# 2     37.06        81           0        5.75
# 3     42.91        87         100       10.36
# 4     53.47        82          92       12.86
# 5     56.17        74          99        4.00

# %%
# Check for nulls
preferred_cities_df.count()
# Out:
# City_ID       402
# City          402
# Country       397
# Date          402
# Lat           402
# Lng           402
# Max Temp      402
# Humidity      402
# Cloudiness    402
# Wind Speed    402
# dtype: int64

# %%
preferred_cities_dferred_cities_dferred_cities_df.dropna()
# Out:
#      City_ID           City Country                 Date      Lat       Lng  \
# 1          1          Sitka      US  2022-04-25 03:21:21  57.0531 -135.3300
# 2          2        Ushuaia      AR  2022-04-25 03:18:12 -54.8000  -68.3000
# 3          3   Punta Arenas      CL  2022-04-25 03:22:13 -53.1500  -70.9167
# 4          4        Mataura      NZ  2022-04-25 03:18:13 -46.1927  168.8643
# 5          5    Port Alfred      ZA  2022-04-25 03:22:13 -33.5906   26.8910
# ..       ...            ...     ...                  ...      ...       ...
# 560      560         Venado      MX  2022-04-25 03:38:56  22.9333 -101.0833
# 561      561        Husavik      IS  2022-04-25 03:38:57  66.0449  -17.3389
# 562      562        Hualmay      PE  2022-04-25 03:38:57 -11.0964  -77.6139
# 563      563  Alice Springs      AU  2022-04-25 03:38:58 -23.7000  133.8833
# 564      564       Yuncheng      CN  2022-04-25 03:38:58  35.0231  110.9928
#
#      Max Temp  Humidity  Cloudiness  Wind Speed
# 1       46.29        76          75        9.22
# 2       37.06        81           0        5.75
# 3       42.91        87         100       10.36
# 4       53.47        82          92       12.86
# 5       56.17        74          99        4.00
# ..        ...       ...         ...         ...
# 560     67.60        72          57       11.41
# 561     41.76        90         100        1.50
# 562     66.94        87          59        9.17
# 563     67.55        77         100        3.44
# 564     78.39        38          14        5.50
#
# [397 rows x 10 columns]

# %%
# Create a DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates
hotel_df = preferred_cities_df[['City', 'Country', 'Max Temp', 'Lat', 'Lng']].copy()
hotel_df['Hotel Name'] = ""
hotel_df.head()
# Out:
#            City Country  Max Temp      Lat       Lng Hotel Name
# 1         Sitka      US     46.29  57.0531 -135.3300
# 2       Ushuaia      AR     37.06 -54.8000  -68.3000
# 3  Punta Arenas      CL     42.91 -53.1500  -70.9167
# 4       Mataura      NZ     53.47 -46.1927  168.8643
# 5   Port Alfred      ZA     56.17 -33.5906   26.8910

# %%
# Get Hotels from Nearby Search

# Set parameters to search for a hotel
params = {'radius': 5000,
         'type': 'lodging',
         'key': g_key
         }

# %%
# Find out what JSON data looks like in another jupyter file - "Google_Nearby_Search.ipynb"

# %%
# Iterate through hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude
    lat = row["Lat"]
    lng = row["Lng"]
    
    # Add the latitude and longitude to location key for the params dictionary
    params["location"] = f"{lat},{lng}"
    
    # Use the search term: "lodging" and our latitude and longitude
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    #Make request and get the JSON data from the serach
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
hotel_df.head(10)
# Out:
#              City Country  Max Temp      Lat       Lng  \
# 1           Sitka      US     46.29  57.0531 -135.3300
# 2         Ushuaia      AR     37.06 -54.8000  -68.3000
# 3    Punta Arenas      CL     42.91 -53.1500  -70.9167
# 4         Mataura      NZ     53.47 -46.1927  168.8643
# 5     Port Alfred      ZA     56.17 -33.5906   26.8910
# 7        Portland      US     66.13  45.5234 -122.6762
# 8         Ardabil      IR     49.55  38.2498   48.2933
# 10  Mar Del Plata      AR     65.88 -38.0023  -57.5575
# 11      Schroeder      BR     69.76 -26.4125  -49.0731
# 14       Hermanus      ZA     58.57 -34.4187   19.2345
#
#                                            Hotel Name
# 1                                      Westmark Sitka
# 2                                     Albatross Hotel
# 3                                          Hotel Hain
# 4                                       Ellie's Villa
# 5                                  The Halyards Hotel
# 7          Embassy Suites by Hilton Portland Downtown
# 8                                         Hotel ideal
# 10                           Gran Hotel Mar del Plata
# 11  Schroeder Imóveis e Waldenir Hang Corretor de ...
# 14                         Misty Waves Boutique Hotel

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temmp</dt><dd>{Max Temp}</dd>
"""

# Store the DataFrame Row
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/74/jdgpfndn3xjf741cwb8t_5280000gn/T/ipykernel_15475/4172009950.py in <module>
#       8
#       9 # Store the DataFrame Row
# ---> 10 hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
#
# NameError: name 'hotel_df' is not defined

# %%
# Add a HEATMAP of temperature for the vacation spots
locations = hotel_df[['Lat', 'Lng']]
max_temp = hotel_df['Max Temp']
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False,
                                max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
fig.add_layer(heat_layer)
# Call the figure to plot the data
fig
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/74/jdgpfndn3xjf741cwb8t_5280000gn/T/ipykernel_15475/633383689.py in <module>
#       1 # Add a HEATMAP of temperature for the vacation spots
# ----> 2 locations = hotel_df[['Lat', 'Lng']]
#       3 max_temp = hotel_df['Max Temp']
#       4 fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
#       5 heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False,
#
# NameError: name 'hotel_df' is not defined

# %%
# Add MARKERS to heatmap 
## loop back up to previous step and add: marker_layer and add_layer
